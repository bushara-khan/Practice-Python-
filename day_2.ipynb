# %%
x = int(input("Enter a number: "))
if (x & 1)==0:
    print("Even")
else:
    print("odd")
# Out:
# Even

# %%
def greeting(name):
    return f"{name}, Good to see you here !. How may I help you?"


print(greeting("Alice"))
# Out:
# Alice, Good to see you here !. How may I help you?

# %%
print("Hello")
# Out:
# Hello
